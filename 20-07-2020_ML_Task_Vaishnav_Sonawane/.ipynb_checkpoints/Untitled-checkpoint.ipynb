# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('house_data.csv')

# %%
df.shape
# Out:
# (21607, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21607 entries, 0 to 21606
# Data columns (total 8 columns):
# id             99 non-null float64
# date           99 non-null object
# price          99 non-null float64
# bedrooms       99 non-null float64
# bathrooms      99 non-null float64
# sqft_living    99 non-null float64
# sqft_lot       99 non-null float64
# floors         99 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                  id         price   bedrooms  bathrooms  sqft_living  \
# count  9.900000e+01  9.900000e+01  99.000000  99.000000    99.000000
# mean   4.664620e+09  5.200763e+05   3.404040   1.989899  2086.383838
# std    2.935212e+09  3.061939e+05   0.794358   0.729236   864.592421
# min    1.600040e+07  1.530000e+05   2.000000   1.000000   770.000000
# 25%    1.914950e+09  3.070000e+05   3.000000   1.500000  1410.000000
# 50%    4.036801e+09  4.300000e+05   3.000000   2.000000  1900.000000
# 75%    7.337325e+09  6.562500e+05   4.000000   2.500000  2570.000000
# max    9.822700e+09  2.000000e+06   5.000000   4.500000  5420.000000
#
#             sqft_lot     floors
# count      99.000000  99.000000
# mean    11478.818182   1.464646
# std     14655.249813   0.511363
# min      1044.000000   1.000000
# 25%      5000.000000   1.000000
# 50%      6720.000000   1.500000
# 75%      9823.000000   2.000000
# max    101930.000000   3.000000

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors'],
#       dtype='object')

# %%
df[['price','sqft_living','sqft_lot', 'floors']]
# Out:
#            price  sqft_living  sqft_lot  floors
# 0       221900.0       1180.0    5650.0     1.0
# 1       538000.0       2570.0    7242.0     2.0
# 2       180000.0        770.0   10000.0     1.0
# 3       604000.0       1960.0    5000.0     1.0
# 4       510000.0       1680.0    8080.0     1.0
# 5      1230000.0       5420.0  101930.0     1.0
# 6       257500.0       1715.0    6819.0     2.0
# 7       291850.0       1060.0    9711.0     1.0
# 8       229500.0       1780.0    7470.0     1.0
# 9       323000.0       1890.0    6560.0     2.0
# 10      662500.0       3560.0    9796.0     1.0
# 11      468000.0       1160.0    6000.0     1.0
# 12      310000.0       1430.0   19901.0     1.5
# 13      400000.0       1370.0    9680.0     1.0
# 14      530000.0       1810.0    4850.0     1.5
# 15      650000.0       2950.0    5000.0     2.0
# 16      395000.0       1890.0   14040.0     2.0
# 17      485000.0       1600.0    4300.0     1.5
# 18      189000.0       1200.0    9850.0     1.0
# ...

# %%
df.price.isnull().sum()
# Out:
# 21508

# %%
df.price.count()
# Out:
# 99

# %%
df.bathrooms.max()
# Out:
# 4.5

# %%
meanprice = df.price.mean()
df.price.fillna(meanprice,inplace = True)

# %%
meanbedrooms = df.bedrooms.mean()
df.bedrooms.fillna(meanbedrooms,inplace = True)

# %%
meanfloors = df.floors.mean()
df.floors.fillna(0,inplace = True)

# %%
meanbathrooms = df.bathrooms.mean()
df.bathrooms.fillna(meanbathrooms,inplace = True)

# %%
df
# Out:
#                  id             date         price  bedrooms  bathrooms  \
# 0      7.129301e+09  20141013T000000  2.219000e+05   3.00000   1.000000
# 1      6.414100e+09  20141209T000000  5.380000e+05   3.00000   2.250000
# 2      5.631500e+09  20150225T000000  1.800000e+05   2.00000   1.000000
# 3      2.487201e+09  20141209T000000  6.040000e+05   4.00000   3.000000
# 4      1.954401e+09  20150218T000000  5.100000e+05   3.00000   2.000000
# 5      7.237550e+09  20140512T000000  1.230000e+06   4.00000   4.500000
# 6      1.321400e+09  20140627T000000  2.575000e+05   3.00000   2.250000
# 7      2.008000e+09  20150115T000000  2.918500e+05   3.00000   1.500000
# 8      2.414600e+09  20150415T000000  2.295000e+05   3.00000   1.000000
# 9      3.793500e+09  20150312T000000  3.230000e+05   3.00000   2.500000
# 10     1.736801e+09  20150403T000000  6.625000e+05   3.00000   2.500000
# 11     9.212900e+09  20140527T000000  4.680000e+05   2.00000   1.000000
# ...

# %%
df.date.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 21577     True
# 21578     True
# 21579     True
# 21580     True
# 21581     True
# 21582     True
# 21583     True
# 21584     True
# 21585     True
# 21586     True
# 21587     True
# 21588     True
# 21589     True
# 21590     True
# 21591     True
# 21592     True
# 21593     True
# 21594     True
# 21595     True
# 21596     True
# 21597     True
# 21598     True
# 21599     True
# 21600     True
# 21601     True
# 21602     True
# 21603     True
# ...

# %%
df.head()
# Out:
#              id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7.129301e+09  20141013T000000  221900.0       3.0       1.00       1180.0
# 1  6.414100e+09  20141209T000000  538000.0       3.0       2.25       2570.0
# 2  5.631500e+09  20150225T000000  180000.0       2.0       1.00        770.0
# 3  2.487201e+09  20141209T000000  604000.0       4.0       3.00       1960.0
# 4  1.954401e+09  20150218T000000  510000.0       3.0       2.00       1680.0
#
#    sqft_lot  floors
# 0    5650.0     1.0
# 1    7242.0     2.0
# 2   10000.0     1.0
# 3    5000.0     1.0
# 4    8080.0     1.0

# %%
df.tail()
# Out:
#        id date          price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 21602 NaN  NaN  520076.313131   3.40404   1.989899          NaN       NaN
# 21603 NaN  NaN  520076.313131   3.40404   1.989899          NaN       NaN
# 21604 NaN  NaN  520076.313131   3.40404   1.989899          NaN       NaN
# 21605 NaN  NaN  520076.313131   3.40404   1.989899          NaN       NaN
# 21606 NaN  NaN  520076.313131   3.40404   1.989899          NaN       NaN
#
#        floors
# 21602     0.0
# 21603     0.0
# 21604     0.0
# 21605     0.0
# 21606     0.0

# %%
df.set_index('bedrooms',inplace = True)

# %%
df.loc[3]
# Out:
#                     id             date      price  bathrooms  sqft_living  \
# bedrooms
# 3.0       7.129301e+09  20141013T000000   221900.0       1.00       1180.0
# 3.0       6.414100e+09  20141209T000000   538000.0       2.25       2570.0
# 3.0       1.954401e+09  20150218T000000   510000.0       2.00       1680.0
# 3.0       1.321400e+09  20140627T000000   257500.0       2.25       1715.0
# 3.0       2.008000e+09  20150115T000000   291850.0       1.50       1060.0
# 3.0       2.414600e+09  20150415T000000   229500.0       1.00       1780.0
# 3.0       3.793500e+09  20150312T000000   323000.0       2.50       1890.0
# 3.0       1.736801e+09  20150403T000000   662500.0       2.50       3560.0
# 3.0       1.141015e+08  20140528T000000   310000.0       1.00       1430.0
# 3.0       6.054650e+09  20141007T000000   400000.0       1.75       1370.0
# 3.0       1.875500e+09  20140731T000000   395000.0       2.00       1890.0
# ...

# %%
df.reset_index(inplace=True)

# %%
df1 = df.copy()

# %%
train = df1.sample(frac=0.75, random_state=1)
test = df1.drop(train.index)

# %%
train
# Out:
#        bedrooms            id             date          price  bathrooms  \
# 19338   3.40404           NaN              NaN  520076.313131   1.989899
# 12150   3.40404           NaN              NaN  520076.313131   1.989899
# 4208    3.40404           NaN              NaN  520076.313131   1.989899
# 4014    3.40404           NaN              NaN  520076.313131   1.989899
# 4421    3.40404           NaN              NaN  520076.313131   1.989899
# 12767   3.40404           NaN              NaN  520076.313131   1.989899
# 275     3.40404           NaN              NaN  520076.313131   1.989899
# 17882   3.40404           NaN              NaN  520076.313131   1.989899
# 10791   3.40404           NaN              NaN  520076.313131   1.989899
# 17889   3.40404           NaN              NaN  520076.313131   1.989899
# 19352   3.40404           NaN              NaN  520076.313131   1.989899
# 14705   3.40404           NaN              NaN  520076.313131   1.989899
# ...

# %%
test.count()
# Out:
# bedrooms       5402
# id               21
# date             21
# price          5402
# bathrooms      5402
# sqft_living      21
# sqft_lot         21
# floors         5402
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
